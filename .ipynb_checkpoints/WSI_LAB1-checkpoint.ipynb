# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

x_axis = np.arange(-10**5,10**5)
#y = np.arange(100)
f_function = 10*x**4 + 3*x**3 - 30*x**2 + 10*x
#g_function = 10*y**4 + 10*x**4 + 3*x**3 - 30*x**2 + 10*x

f_gradient = 40*x**3 + 9*x**2 - 60*x + 10
#g_gradient = [[40*x**3 + 9*x**2 - 60*x + 10],[40*y**3]]


fig, ax = plt.subplots()
ax.plot(x_axis, f_function)

ax.set(xlabel='x', ylabel='y',
       title='f(x)')
ax.grid()


plt.show()

# %%
from mpl_toolkits import mplot3d


def g_function(x, y):
    return 10*y**4 + 10*x**4 + 3*x**3 - 30*x**2 + 10*x

x = np.arange(-10**3,10**3)
y = np.arange(-10**3,10**3)

#x_values, y_values = np.meshgrid(x, y)
#z_values = g_function(x_values, y_values)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(x_values, y_values, z_values, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')
